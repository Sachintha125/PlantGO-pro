# %%
import torch
# from torch.utils.data import DataLoader, Dataset
# from skmultilearn.model_selection import iterative_train_test_split
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
# class ProtDataset(Dataset):
#     def __init__(self, x, y):
#         super(ProtDataset, self).__init__()
#         assert x.shape[0] == y.shape[0] # assuming shape[0] = dataset size
#         self.x = x
#         self.y = y

#     def __len__(self):
#         return self.y.shape[0]

#     def __getitem__(self, index):
#         return self.x[index], self.y[index]

# %%
with open('d:\\year 4\\semester 1\\BT\\BT 4033\\prediction\\labels\\mf_terms_class_order.pkl', 'rb') as f:
    go_terms_order = pickle.load(f)

# %%
with open('d:\\year 4\\semester 1\\BT\\BT 4033\\prediction\\datasets\\mf_dataset.pkl', 'rb') as f:
    prior_dataset = pickle.load(f)

# %%
inputs = np.array([vect['vect'] for vect in prior_dataset.values()])
outputs = np.array([vect['enc_label'] for vect in prior_dataset.values()])

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.2, random_state=42, stratify=outputs, shuffle=True)

# %%
X_train.shape
# Out:
# (12582, 225)

# %%
y_train.shape
# Out:
# (12582, 139)

# %%
train_class_counts = np.sum(y_train == 1, axis=0)
  # Sum along rows for each class
classes = torch.arange(len(train_class_counts))  # Class indices

# %%
print(train_class_counts)
# Out:
# [1048  112   68  204  292  208   48  248  280 1244  204  296   80  212
#   244  280   48   48  168   56  932  524   48  116   48   72   56  224
#    40   88   60   52   48   80  100  436   96 9974  372   40 1164   68
#   140  124   60  228  140   80   60   96  100   40   56   68  144   56
#    72  104  216  120  184   96  232   48   40   56  120  272  144   88
#    80  120  344  120  280   60   92 1160   56   56  112  228   40  132
#    64   56   56  132  396   68   64  120 1872 1448  484  220  120  248
#   108   60  212   80 1168   40  304   48  160  184   48   48   80  236
#    80   44   44   44   44   48  180   80  272  280   72   56   88   48
#    48   48   68   48  132   48   48   48   48  228   68  180  180]

# %%
plt.bar(classes, train_class_counts)
plt.xlabel('Classes')
plt.ylabel('Frequency')
plt.title('Training Class Distribution')
plt.show()

# %%
class_weights = y_train.shape[0]/(train_class_counts)    # from deep fri

# %%
weight_tensor = torch.tensor(class_weights)

# %%
test_class_counts = np.sum(y_test == 1, axis=0)
plt.bar(classes, test_class_counts)
plt.xlabel('Classes')
plt.ylabel('Frequency')
plt.title('Testing Class Distribution')
plt.show()

# %%
# Define the model
class MF_PredictorModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(MF_PredictorModel, self).__init__()
        self.input_layer = nn.Linear(input_size, input_size)
        self.middle_layer = nn.Linear(input_size, input_size)
        self.output_layer = nn.Linear(input_size, output_size)

    def forward(self, x):
        x = self.input_layer(x).relu()
        x = self.middle_layer(x).relu()
        
        x = self.output_layer(x)
        return x

# %%
model = MF_PredictorModel(225, 139)

# %%
# Criterion and Optimizer
criterion = nn.BCEWithLogitsLoss(pos_weight= weight_tensor)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
import matplotlib.pyplot as plt

# Lists to store accuracy values for plotting
train_accuracies = []
test_accuracies = []
train_losses = []
test_losses = []

# %%
def calculate_accuracy(predictions, labels, threshold=0.5):
    """
    Calculate multi-label accuracy.
    - predictions: Model outputs (probabilities after sigmoid).
    - labels: Ground truth labels.
    - threshold: Threshold to convert probabilities to binary labels (default 0.5).
    """
    # Apply threshold to convert probabilities to binary predictions
    predicted_labels = (predictions > threshold).float()
    
    # Correct predictions (element-wise match)
    correct = (predicted_labels == labels).float()
    
    # Accuracy is the average of correctly predicted labels
    accuracy = correct.mean().item()
    return accuracy

# %%
def train_model(model, inputs, labels, criterion, optimizer):
    model.train()  # Set model to training mode

    # Zero the parameter gradients
    optimizer.zero_grad()

    # Forward pass
    outputs = model(inputs)

    # Compute loss
    loss = criterion(outputs, labels)
    train_losses.append(loss.item())

    # Backward pass and optimization
    loss.backward()
    optimizer.step()

    # Calculate accuracy
    probabilities = outputs.sigmoid()  # Convert logits to probabilities
    accuracy = calculate_accuracy(probabilities, labels)
    train_accuracies.append(accuracy)
    # Return the loss
    return loss.item(), accuracy 


# Testing function without batching
def test_model(model, inputs, labels, criterion):
    model.eval()  # Set model to evaluation mode

    with torch.no_grad():  # Disable gradient computation for testing
        # Forward pass
        outputs = model(inputs)

        # Compute loss
        loss = criterion(outputs, labels)
        test_losses.append(loss.item())

    # Apply sigmoid to outputs for multi-label probabilities
    probabilities = outputs.sigmoid()
    accuracy = calculate_accuracy(probabilities, labels)
    test_accuracies.append(accuracy)

    # Return the loss and predictions
    return loss.item(), accuracy

# %%
minmax_scaler = MinMaxScaler(feature_range=(-1, 1))
minmax_scaled_train_data = torch.from_numpy(minmax_scaler.fit_transform(X_train)).float()

# %%
minmax_scaled_test_data = torch.from_numpy(minmax_scaler.transform(X_test)).float()

# %%
train_label = torch.from_numpy(y_train).float()
                               
test_label = torch.from_numpy(y_test).float()

# %%
# Training loop
num_epochs = 250
for epoch in range(num_epochs):
    # Train
    train_loss, train_accuracy = train_model(model, minmax_scaled_train_data, train_label, criterion, optimizer)

    # Test (optional: use a separate test dataset)
    test_loss, test_accuracy = test_model(model, minmax_scaled_test_data, test_label, criterion)

    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, "
          f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/250, Train Loss: 1.3732, Train Accuracy: 0.4871, Test Loss: 1.3647, Test Accuracy: 0.4982
# Epoch 2/250, Train Loss: 1.3647, Train Accuracy: 0.4992, Test Loss: 1.3570, Test Accuracy: 0.5133
# Epoch 3/250, Train Loss: 1.3570, Train Accuracy: 0.5147, Test Loss: 1.3487, Test Accuracy: 0.5377
# Epoch 4/250, Train Loss: 1.3486, Train Accuracy: 0.5393, Test Loss: 1.3394, Test Accuracy: 0.5668
# Epoch 5/250, Train Loss: 1.3392, Train Accuracy: 0.5685, Test Loss: 1.3287, Test Accuracy: 0.5978
# Epoch 6/250, Train Loss: 1.3284, Train Accuracy: 0.6002, Test Loss: 1.3163, Test Accuracy: 0.6248
# Epoch 7/250, Train Loss: 1.3159, Train Accuracy: 0.6274, Test Loss: 1.3021, Test Accuracy: 0.6474
# Epoch 8/250, Train Loss: 1.3014, Train Accuracy: 0.6504, Test Loss: 1.2855, Test Accuracy: 0.6652
# Epoch 9/250, Train Loss: 1.2847, Train Accuracy: 0.6682, Test Loss: 1.2667, Test Accuracy: 0.6800
# Epoch 10/250, Train Loss: 1.2655, Train Accuracy: 0.6829, Test Loss: 1.2453, Test Accuracy: 0.6923
# Epoch 11/250, Train Loss: 1.2438, Train Accuracy: 0.6955, Test Loss: 1.2215, Test Accuracy: 0.7019
# Epoch 12/250, Train Loss: 1.2197, Train Accuracy: 0.7048, Test Loss: 1.1957, Test Accuracy: 0.7103
# Epoch 13/250, Train Loss: 1.1935, Train Accuracy: 0.7131, Test Loss: 1.1679, Test Accuracy: 0.7157
# Epoch 14/250, Train Loss: 1.1652, Train Accuracy: 0.7189, Test Loss: 1.1387, Test Accuracy: 0.7192
# Epoch 15/250, Train Loss: 1.1355, Train Accuracy: 0.7222, Test Loss: 1.1083, Test Accuracy: 0.7217
# Epoch 16/250, Train Loss: 1.1046, Train Accuracy: 0.7248, Test Loss: 1.0771, Test Accuracy: 0.7231
# Epoch 17/250, Train Loss: 1.0729, Train Accuracy: 0.7262, Test Loss: 1.0451, Test Accuracy: 0.7228
# Epoch 18/250, Train Loss: 1.0405, Train Accuracy: 0.7260, Test Loss: 1.0127, Test Accuracy: 0.7245
# Epoch 19/250, Train Loss: 1.0076, Train Accuracy: 0.7277, Test Loss: 0.9797, Test Accuracy: 0.7266
# Epoch 20/250, Train Loss: 0.9743, Train Accuracy: 0.7295, Test Loss: 0.9460, Test Accuracy: 0.7314
# Epoch 21/250, Train Loss: 0.9402, Train Accuracy: 0.7343, Test Loss: 0.9117, Test Accuracy: 0.7420
# Epoch 22/250, Train Loss: 0.9057, Train Accuracy: 0.7444, Test Loss: 0.8770, Test Accuracy: 0.7550
# Epoch 23/250, Train Loss: 0.8710, Train Accuracy: 0.7570, Test Loss: 0.8425, Test Accuracy: 0.7668
# Epoch 24/250, Train Loss: 0.8366, Train Accuracy: 0.7685, Test Loss: 0.8084, Test Accuracy: 0.7785
# Epoch 25/250, Train Loss: 0.8028, Train Accuracy: 0.7796, Test Loss: 0.7751, Test Accuracy: 0.7894
# Epoch 26/250, Train Loss: 0.7698, Train Accuracy: 0.7905, Test Loss: 0.7425, Test Accuracy: 0.8001
# Epoch 27/250, Train Loss: 0.7375, Train Accuracy: 0.8009, Test Loss: 0.7105, Test Accuracy: 0.8081
# Epoch 28/250, Train Loss: 0.7058, Train Accuracy: 0.8087, Test Loss: 0.6795, Test Accuracy: 0.8154
# Epoch 29/250, Train Loss: 0.6750, Train Accuracy: 0.8160, Test Loss: 0.6497, Test Accuracy: 0.8227
# Epoch 30/250, Train Loss: 0.6453, Train Accuracy: 0.8230, Test Loss: 0.6212, Test Accuracy: 0.8313
# Epoch 31/250, Train Loss: 0.6169, Train Accuracy: 0.8313, Test Loss: 0.5941, Test Accuracy: 0.8413
# Epoch 32/250, Train Loss: 0.5897, Train Accuracy: 0.8412, Test Loss: 0.5683, Test Accuracy: 0.8505
# Epoch 33/250, Train Loss: 0.5638, Train Accuracy: 0.8505, Test Loss: 0.5437, Test Accuracy: 0.8591
# Epoch 34/250, Train Loss: 0.5390, Train Accuracy: 0.8593, Test Loss: 0.5203, Test Accuracy: 0.8653
# Epoch 35/250, Train Loss: 0.5153, Train Accuracy: 0.8656, Test Loss: 0.4981, Test Accuracy: 0.8703
# Epoch 36/250, Train Loss: 0.4929, Train Accuracy: 0.8707, Test Loss: 0.4770, Test Accuracy: 0.8761
# Epoch 37/250, Train Loss: 0.4717, Train Accuracy: 0.8762, Test Loss: 0.4571, Test Accuracy: 0.8816
# Epoch 38/250, Train Loss: 0.4516, Train Accuracy: 0.8818, Test Loss: 0.4382, Test Accuracy: 0.8859
# Epoch 39/250, Train Loss: 0.4326, Train Accuracy: 0.8861, Test Loss: 0.4204, Test Accuracy: 0.8910
# Epoch 40/250, Train Loss: 0.4146, Train Accuracy: 0.8912, Test Loss: 0.4036, Test Accuracy: 0.8961
# Epoch 41/250, Train Loss: 0.3978, Train Accuracy: 0.8962, Test Loss: 0.3878, Test Accuracy: 0.9008
# Epoch 42/250, Train Loss: 0.3821, Train Accuracy: 0.9010, Test Loss: 0.3730, Test Accuracy: 0.9052
# Epoch 43/250, Train Loss: 0.3673, Train Accuracy: 0.9055, Test Loss: 0.3589, Test Accuracy: 0.9096
# Epoch 44/250, Train Loss: 0.3534, Train Accuracy: 0.9097, Test Loss: 0.3455, Test Accuracy: 0.9131
# Epoch 45/250, Train Loss: 0.3402, Train Accuracy: 0.9133, Test Loss: 0.3329, Test Accuracy: 0.9163
# Epoch 46/250, Train Loss: 0.3277, Train Accuracy: 0.9166, Test Loss: 0.3211, Test Accuracy: 0.9198
# Epoch 47/250, Train Loss: 0.3161, Train Accuracy: 0.9201, Test Loss: 0.3099, Test Accuracy: 0.9234
# Epoch 48/250, Train Loss: 0.3051, Train Accuracy: 0.9236, Test Loss: 0.2995, Test Accuracy: 0.9257
# Epoch 49/250, Train Loss: 0.2948, Train Accuracy: 0.9258, Test Loss: 0.2896, Test Accuracy: 0.9278
# Epoch 50/250, Train Loss: 0.2850, Train Accuracy: 0.9278, Test Loss: 0.2803, Test Accuracy: 0.9298
# Epoch 51/250, Train Loss: 0.2758, Train Accuracy: 0.9297, Test Loss: 0.2715, Test Accuracy: 0.9320
# Epoch 52/250, Train Loss: 0.2670, Train Accuracy: 0.9318, Test Loss: 0.2631, Test Accuracy: 0.9339
# Epoch 53/250, Train Loss: 0.2587, Train Accuracy: 0.9339, Test Loss: 0.2551, Test Accuracy: 0.9361
# Epoch 54/250, Train Loss: 0.2507, Train Accuracy: 0.9362, Test Loss: 0.2474, Test Accuracy: 0.9379
# Epoch 55/250, Train Loss: 0.2431, Train Accuracy: 0.9380, Test Loss: 0.2400, Test Accuracy: 0.9401
# Epoch 56/250, Train Loss: 0.2359, Train Accuracy: 0.9402, Test Loss: 0.2331, Test Accuracy: 0.9419
# Epoch 57/250, Train Loss: 0.2290, Train Accuracy: 0.9420, Test Loss: 0.2264, Test Accuracy: 0.9436
# Epoch 58/250, Train Loss: 0.2224, Train Accuracy: 0.9438, Test Loss: 0.2201, Test Accuracy: 0.9449
# Epoch 59/250, Train Loss: 0.2162, Train Accuracy: 0.9450, Test Loss: 0.2141, Test Accuracy: 0.9465
# Epoch 60/250, Train Loss: 0.2102, Train Accuracy: 0.9465, Test Loss: 0.2083, Test Accuracy: 0.9478
# Epoch 61/250, Train Loss: 0.2045, Train Accuracy: 0.9478, Test Loss: 0.2028, Test Accuracy: 0.9491
# Epoch 62/250, Train Loss: 0.1990, Train Accuracy: 0.9492, Test Loss: 0.1974, Test Accuracy: 0.9503
# Epoch 63/250, Train Loss: 0.1937, Train Accuracy: 0.9503, Test Loss: 0.1922, Test Accuracy: 0.9514
# Epoch 64/250, Train Loss: 0.1887, Train Accuracy: 0.9515, Test Loss: 0.1873, Test Accuracy: 0.9527
# Epoch 65/250, Train Loss: 0.1839, Train Accuracy: 0.9527, Test Loss: 0.1825, Test Accuracy: 0.9538
# Epoch 66/250, Train Loss: 0.1792, Train Accuracy: 0.9538, Test Loss: 0.1780, Test Accuracy: 0.9549
# Epoch 67/250, Train Loss: 0.1747, Train Accuracy: 0.9549, Test Loss: 0.1737, Test Accuracy: 0.9559
# Epoch 68/250, Train Loss: 0.1705, Train Accuracy: 0.9559, Test Loss: 0.1695, Test Accuracy: 0.9568
# Epoch 69/250, Train Loss: 0.1663, Train Accuracy: 0.9567, Test Loss: 0.1654, Test Accuracy: 0.9578
# Epoch 70/250, Train Loss: 0.1623, Train Accuracy: 0.9577, Test Loss: 0.1615, Test Accuracy: 0.9589
# Epoch 71/250, Train Loss: 0.1585, Train Accuracy: 0.9588, Test Loss: 0.1578, Test Accuracy: 0.9600
# Epoch 72/250, Train Loss: 0.1548, Train Accuracy: 0.9598, Test Loss: 0.1542, Test Accuracy: 0.9610
# Epoch 73/250, Train Loss: 0.1513, Train Accuracy: 0.9608, Test Loss: 0.1508, Test Accuracy: 0.9620
# Epoch 74/250, Train Loss: 0.1478, Train Accuracy: 0.9617, Test Loss: 0.1475, Test Accuracy: 0.9628
# Epoch 75/250, Train Loss: 0.1446, Train Accuracy: 0.9626, Test Loss: 0.1443, Test Accuracy: 0.9637
# Epoch 76/250, Train Loss: 0.1414, Train Accuracy: 0.9635, Test Loss: 0.1413, Test Accuracy: 0.9646
# Epoch 77/250, Train Loss: 0.1384, Train Accuracy: 0.9645, Test Loss: 0.1383, Test Accuracy: 0.9654
# Epoch 78/250, Train Loss: 0.1354, Train Accuracy: 0.9653, Test Loss: 0.1355, Test Accuracy: 0.9662
# Epoch 79/250, Train Loss: 0.1326, Train Accuracy: 0.9662, Test Loss: 0.1328, Test Accuracy: 0.9670
# Epoch 80/250, Train Loss: 0.1298, Train Accuracy: 0.9669, Test Loss: 0.1301, Test Accuracy: 0.9678
# Epoch 81/250, Train Loss: 0.1272, Train Accuracy: 0.9678, Test Loss: 0.1276, Test Accuracy: 0.9685
# Epoch 82/250, Train Loss: 0.1247, Train Accuracy: 0.9684, Test Loss: 0.1251, Test Accuracy: 0.9693
# Epoch 83/250, Train Loss: 0.1222, Train Accuracy: 0.9692, Test Loss: 0.1227, Test Accuracy: 0.9700
# Epoch 84/250, Train Loss: 0.1198, Train Accuracy: 0.9700, Test Loss: 0.1204, Test Accuracy: 0.9707
# Epoch 85/250, Train Loss: 0.1175, Train Accuracy: 0.9706, Test Loss: 0.1181, Test Accuracy: 0.9713
# Epoch 86/250, Train Loss: 0.1152, Train Accuracy: 0.9713, Test Loss: 0.1159, Test Accuracy: 0.9719
# Epoch 87/250, Train Loss: 0.1131, Train Accuracy: 0.9719, Test Loss: 0.1138, Test Accuracy: 0.9726
# Epoch 88/250, Train Loss: 0.1110, Train Accuracy: 0.9725, Test Loss: 0.1118, Test Accuracy: 0.9733
# Epoch 89/250, Train Loss: 0.1089, Train Accuracy: 0.9731, Test Loss: 0.1098, Test Accuracy: 0.9739
# Epoch 90/250, Train Loss: 0.1070, Train Accuracy: 0.9737, Test Loss: 0.1078, Test Accuracy: 0.9745
# Epoch 91/250, Train Loss: 0.1050, Train Accuracy: 0.9744, Test Loss: 0.1060, Test Accuracy: 0.9751
# Epoch 92/250, Train Loss: 0.1032, Train Accuracy: 0.9749, Test Loss: 0.1041, Test Accuracy: 0.9755
# Epoch 93/250, Train Loss: 0.1014, Train Accuracy: 0.9754, Test Loss: 0.1024, Test Accuracy: 0.9760
# Epoch 94/250, Train Loss: 0.0996, Train Accuracy: 0.9758, Test Loss: 0.1006, Test Accuracy: 0.9764
# Epoch 95/250, Train Loss: 0.0979, Train Accuracy: 0.9762, Test Loss: 0.0990, Test Accuracy: 0.9768
# Epoch 96/250, Train Loss: 0.0962, Train Accuracy: 0.9766, Test Loss: 0.0973, Test Accuracy: 0.9772
# Epoch 97/250, Train Loss: 0.0946, Train Accuracy: 0.9770, Test Loss: 0.0957, Test Accuracy: 0.9776
# Epoch 98/250, Train Loss: 0.0930, Train Accuracy: 0.9774, Test Loss: 0.0941, Test Accuracy: 0.9780
# Epoch 99/250, Train Loss: 0.0915, Train Accuracy: 0.9778, Test Loss: 0.0926, Test Accuracy: 0.9784
# Epoch 100/250, Train Loss: 0.0900, Train Accuracy: 0.9782, Test Loss: 0.0912, Test Accuracy: 0.9787
# Epoch 101/250, Train Loss: 0.0886, Train Accuracy: 0.9787, Test Loss: 0.0898, Test Accuracy: 0.9791
# Epoch 102/250, Train Loss: 0.0872, Train Accuracy: 0.9791, Test Loss: 0.0884, Test Accuracy: 0.9794
# Epoch 103/250, Train Loss: 0.0858, Train Accuracy: 0.9794, Test Loss: 0.0870, Test Accuracy: 0.9798
# Epoch 104/250, Train Loss: 0.0844, Train Accuracy: 0.9798, Test Loss: 0.0857, Test Accuracy: 0.9801
# Epoch 105/250, Train Loss: 0.0831, Train Accuracy: 0.9801, Test Loss: 0.0844, Test Accuracy: 0.9805
# Epoch 106/250, Train Loss: 0.0819, Train Accuracy: 0.9805, Test Loss: 0.0832, Test Accuracy: 0.9808
# Epoch 107/250, Train Loss: 0.0806, Train Accuracy: 0.9808, Test Loss: 0.0820, Test Accuracy: 0.9811
# Epoch 108/250, Train Loss: 0.0794, Train Accuracy: 0.9812, Test Loss: 0.0808, Test Accuracy: 0.9814
# Epoch 109/250, Train Loss: 0.0782, Train Accuracy: 0.9814, Test Loss: 0.0796, Test Accuracy: 0.9817
# Epoch 110/250, Train Loss: 0.0771, Train Accuracy: 0.9817, Test Loss: 0.0785, Test Accuracy: 0.9820
# Epoch 111/250, Train Loss: 0.0760, Train Accuracy: 0.9821, Test Loss: 0.0774, Test Accuracy: 0.9824
# Epoch 112/250, Train Loss: 0.0749, Train Accuracy: 0.9824, Test Loss: 0.0763, Test Accuracy: 0.9827
# Epoch 113/250, Train Loss: 0.0738, Train Accuracy: 0.9827, Test Loss: 0.0753, Test Accuracy: 0.9830
# Epoch 114/250, Train Loss: 0.0728, Train Accuracy: 0.9830, Test Loss: 0.0743, Test Accuracy: 0.9832
# Epoch 115/250, Train Loss: 0.0718, Train Accuracy: 0.9832, Test Loss: 0.0733, Test Accuracy: 0.9834
# Epoch 116/250, Train Loss: 0.0708, Train Accuracy: 0.9835, Test Loss: 0.0723, Test Accuracy: 0.9837
# Epoch 117/250, Train Loss: 0.0698, Train Accuracy: 0.9837, Test Loss: 0.0714, Test Accuracy: 0.9839
# Epoch 118/250, Train Loss: 0.0689, Train Accuracy: 0.9840, Test Loss: 0.0705, Test Accuracy: 0.9842
# Epoch 119/250, Train Loss: 0.0679, Train Accuracy: 0.9842, Test Loss: 0.0696, Test Accuracy: 0.9845
# Epoch 120/250, Train Loss: 0.0670, Train Accuracy: 0.9845, Test Loss: 0.0687, Test Accuracy: 0.9847
# Epoch 121/250, Train Loss: 0.0662, Train Accuracy: 0.9847, Test Loss: 0.0678, Test Accuracy: 0.9850
# Epoch 122/250, Train Loss: 0.0653, Train Accuracy: 0.9849, Test Loss: 0.0670, Test Accuracy: 0.9852
# Epoch 123/250, Train Loss: 0.0644, Train Accuracy: 0.9851, Test Loss: 0.0661, Test Accuracy: 0.9854
# Epoch 124/250, Train Loss: 0.0636, Train Accuracy: 0.9853, Test Loss: 0.0653, Test Accuracy: 0.9856
# Epoch 125/250, Train Loss: 0.0628, Train Accuracy: 0.9856, Test Loss: 0.0645, Test Accuracy: 0.9858
# Epoch 126/250, Train Loss: 0.0620, Train Accuracy: 0.9858, Test Loss: 0.0637, Test Accuracy: 0.9860
# Epoch 127/250, Train Loss: 0.0612, Train Accuracy: 0.9860, Test Loss: 0.0630, Test Accuracy: 0.9862
# Epoch 128/250, Train Loss: 0.0605, Train Accuracy: 0.9862, Test Loss: 0.0622, Test Accuracy: 0.9863
# Epoch 129/250, Train Loss: 0.0597, Train Accuracy: 0.9864, Test Loss: 0.0615, Test Accuracy: 0.9866
# Epoch 130/250, Train Loss: 0.0590, Train Accuracy: 0.9866, Test Loss: 0.0608, Test Accuracy: 0.9867
# Epoch 131/250, Train Loss: 0.0583, Train Accuracy: 0.9868, Test Loss: 0.0601, Test Accuracy: 0.9870
# Epoch 132/250, Train Loss: 0.0576, Train Accuracy: 0.9870, Test Loss: 0.0594, Test Accuracy: 0.9871
# Epoch 133/250, Train Loss: 0.0569, Train Accuracy: 0.9872, Test Loss: 0.0587, Test Accuracy: 0.9873
# Epoch 134/250, Train Loss: 0.0563, Train Accuracy: 0.9874, Test Loss: 0.0581, Test Accuracy: 0.9875
# Epoch 135/250, Train Loss: 0.0556, Train Accuracy: 0.9876, Test Loss: 0.0575, Test Accuracy: 0.9877
# Epoch 136/250, Train Loss: 0.0550, Train Accuracy: 0.9878, Test Loss: 0.0568, Test Accuracy: 0.9879
# Epoch 137/250, Train Loss: 0.0543, Train Accuracy: 0.9879, Test Loss: 0.0562, Test Accuracy: 0.9880
# Epoch 138/250, Train Loss: 0.0537, Train Accuracy: 0.9881, Test Loss: 0.0556, Test Accuracy: 0.9882
# Epoch 139/250, Train Loss: 0.0531, Train Accuracy: 0.9882, Test Loss: 0.0550, Test Accuracy: 0.9883
# Epoch 140/250, Train Loss: 0.0525, Train Accuracy: 0.9884, Test Loss: 0.0544, Test Accuracy: 0.9885
# Epoch 141/250, Train Loss: 0.0519, Train Accuracy: 0.9885, Test Loss: 0.0538, Test Accuracy: 0.9886
# Epoch 142/250, Train Loss: 0.0514, Train Accuracy: 0.9887, Test Loss: 0.0533, Test Accuracy: 0.9888
# Epoch 143/250, Train Loss: 0.0508, Train Accuracy: 0.9888, Test Loss: 0.0527, Test Accuracy: 0.9889
# Epoch 144/250, Train Loss: 0.0503, Train Accuracy: 0.9889, Test Loss: 0.0522, Test Accuracy: 0.9891
# Epoch 145/250, Train Loss: 0.0497, Train Accuracy: 0.9890, Test Loss: 0.0517, Test Accuracy: 0.9892
# Epoch 146/250, Train Loss: 0.0492, Train Accuracy: 0.9892, Test Loss: 0.0511, Test Accuracy: 0.9893
# Epoch 147/250, Train Loss: 0.0487, Train Accuracy: 0.9893, Test Loss: 0.0506, Test Accuracy: 0.9894
# Epoch 148/250, Train Loss: 0.0482, Train Accuracy: 0.9894, Test Loss: 0.0501, Test Accuracy: 0.9895
# Epoch 149/250, Train Loss: 0.0477, Train Accuracy: 0.9895, Test Loss: 0.0496, Test Accuracy: 0.9895
# Epoch 150/250, Train Loss: 0.0472, Train Accuracy: 0.9896, Test Loss: 0.0491, Test Accuracy: 0.9897
# Epoch 151/250, Train Loss: 0.0467, Train Accuracy: 0.9897, Test Loss: 0.0486, Test Accuracy: 0.9898
# Epoch 152/250, Train Loss: 0.0462, Train Accuracy: 0.9898, Test Loss: 0.0482, Test Accuracy: 0.9899
# Epoch 153/250, Train Loss: 0.0458, Train Accuracy: 0.9899, Test Loss: 0.0477, Test Accuracy: 0.9900
# Epoch 154/250, Train Loss: 0.0453, Train Accuracy: 0.9899, Test Loss: 0.0472, Test Accuracy: 0.9901
# Epoch 155/250, Train Loss: 0.0448, Train Accuracy: 0.9900, Test Loss: 0.0468, Test Accuracy: 0.9901
# Epoch 156/250, Train Loss: 0.0444, Train Accuracy: 0.9901, Test Loss: 0.0463, Test Accuracy: 0.9902
# Epoch 157/250, Train Loss: 0.0440, Train Accuracy: 0.9902, Test Loss: 0.0459, Test Accuracy: 0.9903
# Epoch 158/250, Train Loss: 0.0435, Train Accuracy: 0.9903, Test Loss: 0.0455, Test Accuracy: 0.9904
# Epoch 159/250, Train Loss: 0.0431, Train Accuracy: 0.9904, Test Loss: 0.0450, Test Accuracy: 0.9905
# Epoch 160/250, Train Loss: 0.0427, Train Accuracy: 0.9905, Test Loss: 0.0446, Test Accuracy: 0.9906
# Epoch 161/250, Train Loss: 0.0423, Train Accuracy: 0.9906, Test Loss: 0.0442, Test Accuracy: 0.9907
# Epoch 162/250, Train Loss: 0.0419, Train Accuracy: 0.9906, Test Loss: 0.0438, Test Accuracy: 0.9908
# Epoch 163/250, Train Loss: 0.0415, Train Accuracy: 0.9908, Test Loss: 0.0434, Test Accuracy: 0.9909
# Epoch 164/250, Train Loss: 0.0411, Train Accuracy: 0.9909, Test Loss: 0.0430, Test Accuracy: 0.9910
# Epoch 165/250, Train Loss: 0.0408, Train Accuracy: 0.9910, Test Loss: 0.0427, Test Accuracy: 0.9911
# Epoch 166/250, Train Loss: 0.0404, Train Accuracy: 0.9910, Test Loss: 0.0423, Test Accuracy: 0.9912
# Epoch 167/250, Train Loss: 0.0400, Train Accuracy: 0.9911, Test Loss: 0.0419, Test Accuracy: 0.9913
# Epoch 168/250, Train Loss: 0.0397, Train Accuracy: 0.9912, Test Loss: 0.0416, Test Accuracy: 0.9914
# Epoch 169/250, Train Loss: 0.0393, Train Accuracy: 0.9913, Test Loss: 0.0412, Test Accuracy: 0.9914
# Epoch 170/250, Train Loss: 0.0390, Train Accuracy: 0.9914, Test Loss: 0.0409, Test Accuracy: 0.9915
# Epoch 171/250, Train Loss: 0.0386, Train Accuracy: 0.9915, Test Loss: 0.0405, Test Accuracy: 0.9916
# Epoch 172/250, Train Loss: 0.0383, Train Accuracy: 0.9915, Test Loss: 0.0402, Test Accuracy: 0.9916
# Epoch 173/250, Train Loss: 0.0380, Train Accuracy: 0.9916, Test Loss: 0.0398, Test Accuracy: 0.9917
# Epoch 174/250, Train Loss: 0.0376, Train Accuracy: 0.9917, Test Loss: 0.0395, Test Accuracy: 0.9918
# Epoch 175/250, Train Loss: 0.0373, Train Accuracy: 0.9918, Test Loss: 0.0392, Test Accuracy: 0.9919
# Epoch 176/250, Train Loss: 0.0370, Train Accuracy: 0.9919, Test Loss: 0.0389, Test Accuracy: 0.9919
# Epoch 177/250, Train Loss: 0.0367, Train Accuracy: 0.9919, Test Loss: 0.0386, Test Accuracy: 0.9920
# Epoch 178/250, Train Loss: 0.0364, Train Accuracy: 0.9920, Test Loss: 0.0383, Test Accuracy: 0.9921
# Epoch 179/250, Train Loss: 0.0361, Train Accuracy: 0.9920, Test Loss: 0.0379, Test Accuracy: 0.9921
# Epoch 180/250, Train Loss: 0.0358, Train Accuracy: 0.9921, Test Loss: 0.0376, Test Accuracy: 0.9922
# Epoch 181/250, Train Loss: 0.0355, Train Accuracy: 0.9922, Test Loss: 0.0373, Test Accuracy: 0.9922
# Epoch 182/250, Train Loss: 0.0352, Train Accuracy: 0.9922, Test Loss: 0.0371, Test Accuracy: 0.9923
# Epoch 183/250, Train Loss: 0.0349, Train Accuracy: 0.9923, Test Loss: 0.0368, Test Accuracy: 0.9923
# Epoch 184/250, Train Loss: 0.0346, Train Accuracy: 0.9923, Test Loss: 0.0365, Test Accuracy: 0.9924
# Epoch 185/250, Train Loss: 0.0344, Train Accuracy: 0.9924, Test Loss: 0.0362, Test Accuracy: 0.9924
# Epoch 186/250, Train Loss: 0.0341, Train Accuracy: 0.9924, Test Loss: 0.0359, Test Accuracy: 0.9924
# Epoch 187/250, Train Loss: 0.0338, Train Accuracy: 0.9925, Test Loss: 0.0356, Test Accuracy: 0.9925
# Epoch 188/250, Train Loss: 0.0336, Train Accuracy: 0.9925, Test Loss: 0.0354, Test Accuracy: 0.9926
# Epoch 189/250, Train Loss: 0.0333, Train Accuracy: 0.9926, Test Loss: 0.0351, Test Accuracy: 0.9926
# Epoch 190/250, Train Loss: 0.0331, Train Accuracy: 0.9926, Test Loss: 0.0348, Test Accuracy: 0.9927
# Epoch 191/250, Train Loss: 0.0328, Train Accuracy: 0.9927, Test Loss: 0.0346, Test Accuracy: 0.9927
# Epoch 192/250, Train Loss: 0.0326, Train Accuracy: 0.9927, Test Loss: 0.0343, Test Accuracy: 0.9928
# Epoch 193/250, Train Loss: 0.0323, Train Accuracy: 0.9928, Test Loss: 0.0341, Test Accuracy: 0.9928
# Epoch 194/250, Train Loss: 0.0321, Train Accuracy: 0.9928, Test Loss: 0.0338, Test Accuracy: 0.9929
# Epoch 195/250, Train Loss: 0.0318, Train Accuracy: 0.9929, Test Loss: 0.0336, Test Accuracy: 0.9929
# Epoch 196/250, Train Loss: 0.0316, Train Accuracy: 0.9929, Test Loss: 0.0333, Test Accuracy: 0.9930
# Epoch 197/250, Train Loss: 0.0314, Train Accuracy: 0.9929, Test Loss: 0.0331, Test Accuracy: 0.9930
# Epoch 198/250, Train Loss: 0.0311, Train Accuracy: 0.9930, Test Loss: 0.0328, Test Accuracy: 0.9931
# Epoch 199/250, Train Loss: 0.0309, Train Accuracy: 0.9930, Test Loss: 0.0326, Test Accuracy: 0.9931
# Epoch 200/250, Train Loss: 0.0307, Train Accuracy: 0.9931, Test Loss: 0.0324, Test Accuracy: 0.9931
# Epoch 201/250, Train Loss: 0.0305, Train Accuracy: 0.9931, Test Loss: 0.0321, Test Accuracy: 0.9932
# Epoch 202/250, Train Loss: 0.0303, Train Accuracy: 0.9932, Test Loss: 0.0319, Test Accuracy: 0.9932
# Epoch 203/250, Train Loss: 0.0300, Train Accuracy: 0.9932, Test Loss: 0.0317, Test Accuracy: 0.9933
# Epoch 204/250, Train Loss: 0.0298, Train Accuracy: 0.9932, Test Loss: 0.0315, Test Accuracy: 0.9933
# Epoch 205/250, Train Loss: 0.0296, Train Accuracy: 0.9933, Test Loss: 0.0312, Test Accuracy: 0.9934
# Epoch 206/250, Train Loss: 0.0294, Train Accuracy: 0.9933, Test Loss: 0.0310, Test Accuracy: 0.9934
# Epoch 207/250, Train Loss: 0.0292, Train Accuracy: 0.9934, Test Loss: 0.0308, Test Accuracy: 0.9935
# Epoch 208/250, Train Loss: 0.0290, Train Accuracy: 0.9935, Test Loss: 0.0306, Test Accuracy: 0.9935
# Epoch 209/250, Train Loss: 0.0288, Train Accuracy: 0.9935, Test Loss: 0.0304, Test Accuracy: 0.9936
# Epoch 210/250, Train Loss: 0.0286, Train Accuracy: 0.9935, Test Loss: 0.0302, Test Accuracy: 0.9936
# Epoch 211/250, Train Loss: 0.0284, Train Accuracy: 0.9936, Test Loss: 0.0300, Test Accuracy: 0.9937
# Epoch 212/250, Train Loss: 0.0283, Train Accuracy: 0.9936, Test Loss: 0.0298, Test Accuracy: 0.9937
# Epoch 213/250, Train Loss: 0.0281, Train Accuracy: 0.9937, Test Loss: 0.0296, Test Accuracy: 0.9938
# Epoch 214/250, Train Loss: 0.0279, Train Accuracy: 0.9937, Test Loss: 0.0294, Test Accuracy: 0.9938
# Epoch 215/250, Train Loss: 0.0277, Train Accuracy: 0.9938, Test Loss: 0.0292, Test Accuracy: 0.9939
# Epoch 216/250, Train Loss: 0.0275, Train Accuracy: 0.9938, Test Loss: 0.0290, Test Accuracy: 0.9939
# Epoch 217/250, Train Loss: 0.0273, Train Accuracy: 0.9939, Test Loss: 0.0288, Test Accuracy: 0.9939
# Epoch 218/250, Train Loss: 0.0272, Train Accuracy: 0.9939, Test Loss: 0.0286, Test Accuracy: 0.9940
# Epoch 219/250, Train Loss: 0.0270, Train Accuracy: 0.9940, Test Loss: 0.0284, Test Accuracy: 0.9940
# Epoch 220/250, Train Loss: 0.0268, Train Accuracy: 0.9940, Test Loss: 0.0282, Test Accuracy: 0.9940
# Epoch 221/250, Train Loss: 0.0267, Train Accuracy: 0.9941, Test Loss: 0.0280, Test Accuracy: 0.9941
# Epoch 222/250, Train Loss: 0.0265, Train Accuracy: 0.9941, Test Loss: 0.0278, Test Accuracy: 0.9941
# Epoch 223/250, Train Loss: 0.0263, Train Accuracy: 0.9942, Test Loss: 0.0277, Test Accuracy: 0.9942
# Epoch 224/250, Train Loss: 0.0262, Train Accuracy: 0.9942, Test Loss: 0.0275, Test Accuracy: 0.9942
# Epoch 225/250, Train Loss: 0.0260, Train Accuracy: 0.9942, Test Loss: 0.0273, Test Accuracy: 0.9942
# Epoch 226/250, Train Loss: 0.0258, Train Accuracy: 0.9943, Test Loss: 0.0271, Test Accuracy: 0.9942
# Epoch 227/250, Train Loss: 0.0257, Train Accuracy: 0.9943, Test Loss: 0.0270, Test Accuracy: 0.9943
# Epoch 228/250, Train Loss: 0.0255, Train Accuracy: 0.9943, Test Loss: 0.0268, Test Accuracy: 0.9943
# Epoch 229/250, Train Loss: 0.0254, Train Accuracy: 0.9943, Test Loss: 0.0266, Test Accuracy: 0.9943
# Epoch 230/250, Train Loss: 0.0252, Train Accuracy: 0.9944, Test Loss: 0.0264, Test Accuracy: 0.9944
# Epoch 231/250, Train Loss: 0.0251, Train Accuracy: 0.9944, Test Loss: 0.0263, Test Accuracy: 0.9944
# Epoch 232/250, Train Loss: 0.0249, Train Accuracy: 0.9944, Test Loss: 0.0261, Test Accuracy: 0.9945
# Epoch 233/250, Train Loss: 0.0248, Train Accuracy: 0.9945, Test Loss: 0.0260, Test Accuracy: 0.9945
# Epoch 234/250, Train Loss: 0.0246, Train Accuracy: 0.9945, Test Loss: 0.0258, Test Accuracy: 0.9945
# Epoch 235/250, Train Loss: 0.0245, Train Accuracy: 0.9945, Test Loss: 0.0256, Test Accuracy: 0.9946
# Epoch 236/250, Train Loss: 0.0243, Train Accuracy: 0.9946, Test Loss: 0.0255, Test Accuracy: 0.9946
# Epoch 237/250, Train Loss: 0.0242, Train Accuracy: 0.9946, Test Loss: 0.0253, Test Accuracy: 0.9946
# Epoch 238/250, Train Loss: 0.0240, Train Accuracy: 0.9946, Test Loss: 0.0252, Test Accuracy: 0.9946
# Epoch 239/250, Train Loss: 0.0239, Train Accuracy: 0.9947, Test Loss: 0.0250, Test Accuracy: 0.9946
# Epoch 240/250, Train Loss: 0.0238, Train Accuracy: 0.9947, Test Loss: 0.0249, Test Accuracy: 0.9947
# Epoch 241/250, Train Loss: 0.0236, Train Accuracy: 0.9947, Test Loss: 0.0247, Test Accuracy: 0.9947
# Epoch 242/250, Train Loss: 0.0235, Train Accuracy: 0.9947, Test Loss: 0.0246, Test Accuracy: 0.9947
# Epoch 243/250, Train Loss: 0.0234, Train Accuracy: 0.9948, Test Loss: 0.0244, Test Accuracy: 0.9947
# Epoch 244/250, Train Loss: 0.0232, Train Accuracy: 0.9948, Test Loss: 0.0243, Test Accuracy: 0.9947
# Epoch 245/250, Train Loss: 0.0231, Train Accuracy: 0.9948, Test Loss: 0.0242, Test Accuracy: 0.9948
# Epoch 246/250, Train Loss: 0.0230, Train Accuracy: 0.9949, Test Loss: 0.0240, Test Accuracy: 0.9948
# Epoch 247/250, Train Loss: 0.0228, Train Accuracy: 0.9949, Test Loss: 0.0239, Test Accuracy: 0.9948
# Epoch 248/250, Train Loss: 0.0227, Train Accuracy: 0.9949, Test Loss: 0.0237, Test Accuracy: 0.9948
# Epoch 249/250, Train Loss: 0.0226, Train Accuracy: 0.9949, Test Loss: 0.0236, Test Accuracy: 0.9949
# Epoch 250/250, Train Loss: 0.0225, Train Accuracy: 0.9950, Test Loss: 0.0235, Test Accuracy: 0.9949

# %%
torch.save(model.state_dict(), 'mf_predictor_final.pt')

# %%
# Plotting the accuracies
plt.figure(figsize=(10, 6))
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Train Accuracy', color='b', linestyle='-', marker='o')
plt.plot(range(1, num_epochs + 1), test_accuracies, label='Test Accuracy', color='r', linestyle='-', marker='x')

plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss', color='g', linestyle='-', marker='o')
plt.plot(range(1, num_epochs + 1), test_losses, label='Test Loss', color='y', linestyle='-', marker='x')

plt.title('Training and Testing Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
true_labels = y_test.astype(int)

model.eval()
with torch.no_grad():
    # Forward pass to get model predictions
    outputs = model(minmax_scaled_test_data).sigmoid().numpy()
predicted_labels = (outputs > 0.5).astype(int)

# %%
from sklearn.metrics import classification_report
cr = classification_report(true_labels, predicted_labels, output_dict= True, target_names= go_terms_order)
report_df = pd.DataFrame(cr).transpose()
# Plot the classification report as a heatmap
plt.figure(figsize=(10, 50))  # Increased figure size for better spacing
sns.heatmap(report_df.iloc[:-1, :-1].astype(float), annot=True, cmap="Blues", fmt='.2f', cbar=True, 
            annot_kws={"size": 12})  # Increase the size of the annotation text

# Customize the plot for better visibility
plt.title("Classification Report", fontsize=16)
plt.ylabel("Classes", fontsize=14)
plt.xlabel("Metrics (Precision, Recall, F1-score)", fontsize=14)
plt.xticks(np.arange(3) + 0.5, ['Precision', 'Recall', 'F1-score'], rotation=45, fontsize=12)
plt.yticks(rotation=0, fontsize=12)  # Increase font size for y-axis labels

# Adjust layout to avoid overlapping
plt.tight_layout(pad=5)  # Increase padding between plot elements

# Show the plot
plt.show()
# Out:
# c:\Users\sachintha\anaconda3\envs\ppi_dl\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, ConfusionMatrixDisplay
# To calculate the overall ROC curve across all labels
# Flatten the labels and predictions for combined ROC
y_true_flat = true_labels.ravel()
y_pred_flat = outputs.ravel()

fpr_all, tpr_all, _ = roc_curve(y_true_flat, y_pred_flat)
roc_auc_all = auc(fpr_all, tpr_all)

print(f"Overall ROC AUC: {roc_auc_all:.2f}")

# Plot combined ROC
plt.figure()
plt.plot(fpr_all, tpr_all, color='darkorange', lw=2, label=f'Overall ROC AUC = {roc_auc_all:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Overall ROC Curve for Multi-label Classification')
plt.legend(loc="lower right")
plt.show()
# Out:
# Overall ROC AUC: 1.00

# %%
precision_all, recall_all, _ = precision_recall_curve(y_true_flat, y_pred_flat)
pr_auc_all = auc(recall_all, precision_all)

print(f"Overall PR AUC: {pr_auc_all:.2f}")

# Plot combined PR curve
plt.figure()
plt.plot(recall_all, precision_all, color='darkorange', lw=2, label=f'Overall PR AUC = {pr_auc_all:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Overall Precision-Recall Curve for Multi-label Classification')
plt.legend(loc="lower left")
plt.show()
# Out:
# Overall PR AUC: 0.96

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, ConfusionMatrixDisplay
# Calculate AUROC and AUPR for each label
roc_auc_values = []
pr_auc_values = []
fprs, tprs, precisions, recalls = [], [], [], []

for i in range(120):
    fpr, tpr, _ = roc_curve(true_labels[:, i], outputs[:, i])
    roc_auc = auc(fpr, tpr)
    roc_auc_values.append(roc_auc)
    fprs.append(fpr)
    tprs.append(tpr)

    precision, recall, _ = precision_recall_curve(true_labels[:, i], outputs[:, i])
    pr_auc = auc(recall, precision)
    pr_auc_values.append(pr_auc)
    precisions.append(precision)
    recalls.append(recall)

# Macro AUROC and AUPR
macro_roc_auc = np.mean(roc_auc_values)
macro_pr_auc = np.mean(pr_auc_values)

# Micro AUROC and AUPR
fpr_micro, tpr_micro, _ = roc_curve(true_labels.ravel(), outputs.ravel())
micro_roc_auc = auc(fpr_micro, tpr_micro)

precision_micro, recall_micro, _ = precision_recall_curve(true_labels.ravel(), outputs.ravel())
micro_pr_auc = auc(recall_micro, precision_micro)

# Plot AUROC and AUPR Violin Plots
# auc_df = pd.DataFrame({
#     'Metric': ['ROC AUC'] * len(roc_auc_values) + ['PR AUC'] * len(pr_auc_values),
#     'Value': roc_auc_values + pr_auc_values
# })

# plt.figure(figsize=(12, 6))
# sns.violinplot(x='Metric', y='Value', data=auc_df)
# plt.title('Distribution of AUROC and AUPR')
# # plt.savefig('auroc_aupr_violin_plot.png')
# plt.show()

# Plot ROC and PR Curves
plt.figure(figsize=(12, 6))

# Plot ROC Curves
plt.subplot(1, 2, 1)
for i in range(120):
    plt.plot(fprs[i], tprs[i], label=f'Label {i} (AUC = {roc_auc_values[i]:.2f})')
plt.plot(fpr_micro, tpr_micro, label=f'Micro Average (AUC = {micro_roc_auc:.2f})', linestyle='--', color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve (Macro AUC = {macro_roc_auc:.2f})')
# plt.legend(loc='best')

# Plot PR Curves
plt.subplot(1, 2, 2)
for i in range(120):
    plt.plot(recalls[i], precisions[i], label=f'Label {i} (AUC = {pr_auc_values[i]:.2f})')
plt.plot(recall_micro, precision_micro, label=f'Micro Average (AUC = {micro_pr_auc:.2f})', linestyle='--', color='red')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title(f'Precision-Recall Curve (Macro AUC = {macro_pr_auc:.2f})')
# plt.legend(loc='best')

plt.tight_layout()
# plt.savefig('roc_pr_curves.png')
plt.show()

# Compute Confusion Matrix: Calculate TP, FP, TN, FN for each label and sum them
TP, FP, TN, FN = 0, 0, 0, 0
for i in range(120):
    predicted = (true_labels[:, i] >= 0.5).astype(int)
    actual = true_labels[:, i]
    
    tp = np.sum((predicted == 1) & (actual == 1), axis=0)
    fp = np.sum((predicted == 1) & (actual == 0), axis=0)
    tn = np.sum((predicted == 0) & (actual == 0), axis=0)
    fn = np.sum((predicted == 0) & (actual == 1), axis=0)

    TP += tp
    FP += fp
    TN += tn
    FN += fn

# Final aggregated confusion matrix
conf_matrix = np.array([[TP, FP], [FN, TN]])

# Plot aggregated confusion matrix
disp = ConfusionMatrixDisplay(conf_matrix, display_labels=['Positive', 'Negative'])
plt.figure(figsize=(8, 6))
disp.plot(cmap=plt.cm.Blues)
plt.title('Aggregated Confusion Matrix')
# plt.savefig('confusion_matrix.png')
plt.show()

# %%
# Number of classes (columns)
num_classes = true_labels.shape[1]

# Initialize a dictionary to store the metrics for each class
metrics_per_class = {}

# %%
# Iterate over each class (column)
for class_idx in range(num_classes):
    y_true = true_labels[:, class_idx]
    y_pred = predicted_labels[:, class_idx]
    
    # Calculate TP, TN, FP, FN
    tp = np.sum((y_true == 1) & (y_pred == 1), axis=0)
    tn = np.sum((y_true == 0) & (y_pred == 0), axis=0)
    fp = np.sum((y_true == 0) & (y_pred == 1), axis=0)
    fn = np.sum((y_true == 1) & (y_pred == 0), axis=0)
    
    # Store the results in the dictionary
    metrics_per_class[f'Class {class_idx}'] = {
        'TP': tp,
        'TN': tn,
        'FP': fp,
        'FN': fn
    }

# %%
metrics_df = pd.DataFrame(metrics_per_class).T
metrics_df.head()
# Out:
#           TP    TN  FP  FN
# Class 0  262  2819  65   0
# Class 1   28  3118   0   0
# Class 2   17  3105  24   0
# Class 3   51  3092   3   0
# Class 4   73  3053  20   0

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Function to plot confusion matrices for each class
def plot_confusion_matrices(metrics_df, per_row=4):
    num_classes = len(metrics_df)
    rows = (num_classes + per_row - 1) // per_row  # Calculate required rows
    
    fig, axes = plt.subplots(rows, per_row, figsize=(5 * per_row, 5 * rows))
    axes = axes.flatten()  # Flatten axes for easy iteration
    
    for idx, (class_name, metrics) in enumerate(metrics_df.iterrows()):
        # Extract confusion matrix values
        tp, fn, fp, tn = metrics['TP'], metrics['FN'], metrics['FP'], metrics['TN']
        confusion_matrix = np.array([[tp, fn], [fp, tn]])  # Arrange elements accordingly
        
        # Plot using sklearn
        disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=['Positive', 'Negative'])
        disp.plot(cmap=plt.cm.Blues, ax=axes[idx])
        axes[idx].set_title(f"Confusion Matrix for {class_name}")
    
    # Hide any unused subplots
    for idx in range(len(metrics_df), len(axes)):
        fig.delaxes(axes[idx])

    plt.tight_layout()
    plt.show()

# %%
plot_confusion_matrices(metrics_df, per_row=4)
